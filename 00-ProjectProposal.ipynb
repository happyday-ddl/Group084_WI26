# %% [markdown]
# # COGS 108 - Project Proposal
#
# ## Authors

# %% [markdown]
# Zhengyin Yang : Find relevant references, prior work, and also brainstorm the background.
#
# Yanbai Li : Obtain data from the references and scheduled timeline for this project.
#
# Alisa Yang : Come up with hypothesis.
#
# Lily Cheng : Analyze Data.
#
# Keyuan Wang: Find research question.

# %% [markdown]
# ## Research Question

# %% [markdown]
# From 2022 to 2024 at UC San Diego (UCSD), how do transfer-admit GPA distributions differ across ten selected majors, and how are these patterns related to major-level alumni earnings? Using data aggregated at the major × year level, we will describe admitted-GPA distributions with mean/median, standard deviation, and key percentiles (10th/25th/75th) and estimate year-to-year trends for each major. We will then merge in major-specific earnings metrics (e.g., median annual wages 2 and 5 years after graduation) and test whether majors with higher or increasing salary outcomes also show rising GPA selectivity over time. In terms of analysis, we will use correlation and regression analysis methods to relate grade point average (GPA) and alumni salary data, in order to assess the strength and significance of these relationships. The final deliverables will identify (1) which of the ten majors have the most selective GPA distributions, (2) which majors show the fastest GPA shifts, and (3) whether alumni earnings help explain or predict changes in GPA selectivity at UCSD.

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# Choosing a university major is a crucial decision that impacts a student's academic trajectory and future career prospects. In recent years, there has been increasing attention to the "return on investment" of higher education, with prospective students often weighing the academic difficulty of a major against its potential graduate earnings. For transfer students—who typically have more defined career goals upon entering university—the competitiveness of admission (measured by the GPA distribution of admitted students (10th, 25th, and 75th percentiles)) is a primary evaluation criterion. This study uses the University of California, San Diego (UCSD) as a case study, a leading public research university where transfer admission selectivity and GPA thresholds vary significantly across different disciplines.
#
# Previous research has confirmed a significant but nuanced link between university admission difficulty and post-graduation earnings. Data from the University of California Information Center suggests this relationship is particularly pronounced at highly competitive institutions like UCSD, especially in fields such as mechanical engineering and computer science, where graduates consistently rank among the highest earners five years after graduation. On the other hand, some "pre-professional" majors, such as human biology, maintain high GPA admission thresholds despite potentially lower undergraduate earnings compared to technical fields. This is often because these students go on to pursue advanced medical degrees, indicating that "admission difficulty" is not solely determined by current average salaries but also by long-term academic value.
#
# Labor market conditions and alumni salary signals have also been shown to influence student demand, and consequently, the academic standards required for admission. It is widely believed that students tend to gravitate towards majors perceived to have higher economic returns, such as STEM fields and applied social sciences like business psychology. This shift in demand leads to increased admission difficulty and higher GPA admission thresholds. For example, UCSD's computer science program consistently maintains higher GPA requirements than humanities disciplines like history, directly reflecting its leading position in alumni earnings data.
#
# Despite these observations, there is a lack of localized research specifically examining the year-to-year changes in UCSD's admission GPA distribution (2022-2024) and its correlation with real-time average salary trends for specific majors. While general research suggests that a 10% increase in expected salary increases the likelihood of students choosing a particular major by nearly 14% to 18%, it remains unclear whether these enrollment preferences immediately translate into quantifiable changes in the 10th, 25th, and 75th percentiles of matriculation GPA. This project aims to bridge the gap between educational enrollment data and labor market wage signals by analyzing ten different academic programs at the University of California, San Diego (UCSD), spanning fields from history to mechanical engineering.
#
# ### References
#
# 1. University of California. (2025). *Transfers by Major: Admitted GPA and Outcomes*. UC Information Center.
#    https://www.universityofcalifornia.edu/about-us/information-center/transfers-major
#
# 2. BestColleges. (2025). *Does College Selectivity Predict Earnings? Sort of.*
#    https://www.bestcolleges.com/news/does-college-selectivity-predict-earnings/
#
# 3. Baker, R. B., et al. (2018). *The effect of labor market information on community college students’ major choice*. Economics of Education Review.
#    https://edpolicy.umich.edu/sites/epi/files/uploads/02-2017-labor-market-major-choice.pdf
#
# 4. NYU News. (2024). *Study finds that a college degree yields a significant return on investment*.
#    https://www.nyu.edu/about/news-publications/news/2024/march/study-of-5-8-million-americans-finds-that-a-college-degree-yield.html

# %% [markdown]
# ## Hypothesis

# %% [markdown]
# We hypothesize that higher post-graduation salaries for a major result in a larger and more academically qualified applicant pool, leading to a measurable increase in the average admitted GPA for transfer students in that major over time. This will result in a significant positive correlation between changes in major-level median salary and changes in GPA selectivity across the observed three-year period.

# %% [markdown]
# ## Data

# %% [markdown]
# i)
#
# Variables:
# Major: The ten selected
# Mean/median admitted GPA: Central tendency.
# UCSD admitted GPA: Standard deviation of admitted GPAs.
# Median Salary: The median annual salary for graduates of that major. This is the key causal variable for the hypothesis
#
# Observations:
# 10 majors within 3 years, minimal observation would be 30
#
# Who/what/how would these data be collected?
# The data would be downloaded from official websites and compiled into the required format
#
# How would these data be stored/organized?
# The data is stored in a long-format structure where each row represents a unique major-year observation; for instance, the first ten rows contain the admission GPA and salary data for all ten selected majors in the year 2022, followed by the next ten rows for 2023, and the final ten rows for 2024.
#
#
#
# ii)
#
# https://www.universityofcalifornia.edu/about-us/information-center/transfers-major   From here, we can obtain the admission GPA for different majors, the admission rate for different majors, and the number of admitted students for different majors. Important variables we may use  include major, admission GPA (mean/median), standard deviation of admitted GPA, admission rate, and number of admitted students by major.
#
#
# https://www.universityofcalifornia.edu/about-us/information-center/uc-alumni-work From here, we can see the income levels of UCSD graduates in different majors 2, 5, and 10 years after graduation, including the average, median, 25th percentile, and 75th percentile. Important variables we may use include major, years after graduation (2, 5, and 10 years), and income measures, such as average salary, median salary, 25th percentile, and 75th percentile.
#
# https://www.universityofcalifornia.edu/about-us/information-center/uc-alumni-career-pathways  From here, we can obtain information on the employment and further education paths of University of California graduates after they receive their degrees, including: information on the companies and organizations that employ UC graduates, the jobs and roles that UC graduates hold throughout their careers, the types of skills UC alumni report possessing, and the skills demanded by the California job market. But we will use the UCSD-only data for all the things above.  Variables we may use  include major, employment status, job titles, industries, employers, skills reported by alumni, and years after graduation.

# %% [markdown]
# ## Ethics
#
# Instructions: Keep the contents of this cell. For each item on the checklist
# -  put an X there if you've considered the item
# -  IF THE ITEM IS RELEVANT place a short paragraph after the checklist item discussing the issue.
#
# Items on this checklist are meant to provoke discussion among good-faith actors who take their ethical responsibilities seriously. Your teams will document these discussions and decisions for posterity using this section.  You don't have to solve these problems, you just have to acknowledge any potential harm no matter how unlikely.
#
# Here is a [list of real world examples](https://deon.drivendata.org/examples/) for each item in the checklist that can refer to.
#
# [![Deon badge](https://img.shields.io/badge/ethics%20checklist-deon-brightgreen.svg?style=popout-square)](http://deon.drivendata.org/)
#
# ### A. Data Collection
#  - [X] **A.1 Informed consent**: If there are human subjects, have they given informed consent, where subjects affirmatively opt-in and have a clear understanding of the data uses to which they consent?
#
# > Example of how to use the checkbox, and also of how you can put in a short paragraph that discusses the way this checklist item affects your project.  Remove this paragraph and the X in the checkbox before you fill this out for your project
#
#  - [X] **A.2 Collection bias**: Have we considered sources of bias that could be introduced during data collection and survey design and taken steps to mitigate those?
#  - [X] **A.3 Limit PII exposure**: Have we considered ways to minimize exposure of personally identifiable information (PII) for example through anonymization or not collecting information that isn't relevant for analysis?
#  - [X] **A.4 Downstream bias mitigation**: Have we considered ways to enable testing downstream results for biased outcomes (e.g., collecting data on protected group status like race or gender)?
#
# ### B. Data Storage
#  - [X] **B.1 Data security**: Do we have a plan to protect and secure data (e.g., encryption at rest and in transit, access controls on internal users and third parties, access logs, and up-to-date software)?
#  - [X] **B.2 Right to be forgotten**: Do we have a mechanism through which an individual can request their personal information be removed?
#  - [X] **B.3 Data retention plan**: Is there a schedule or plan to delete the data after it is no longer needed?
#
# ### C. Analysis
#  - [X] **C.1 Missing perspectives**: Have we sought to address blindspots in the analysis through engagement with relevant stakeholders (e.g., checking assumptions and discussing implications with affected communities and subject matter experts)?
#  - [X] **C.2 Dataset bias**: Have we examined the data for possible sources of bias and taken steps to mitigate or address these biases (e.g., stereotype perpetuation, confirmation bias, imbalanced classes, or omitted confounding variables)?
#  - [X] **C.3 Honest representation**: Are our visualizations, summary statistics, and reports designed to honestly represent the underlying data?
#  - [X] **C.4 Privacy in analysis**: Have we ensured that data with PII are not used or displayed unless necessary for the analysis?
#  - [X] **C.5 Auditability**: Is the process of generating the analysis well documented and reproducible if we discover issues in the future?
#
# ### D. Modeling
#  - [X] **D.1 Proxy discrimination**: Have we ensured that the model does not rely on variables or proxies for variables that are unfairly discriminatory?
#  - [X] **D.2 Fairness across groups**: Have we tested model results for fairness with respect to different affected groups (e.g., tested for disparate error rates)?
#  - [X] **D.3 Metric selection**: Have we considered the effects of optimizing for our defined metrics and considered additional metrics?
#  - [X] **D.4 Explainability**: Can we explain in understandable terms a decision the model made in cases where a justification is needed?
#  - [X] **D.5 Communicate limitations**: Have we communicated the shortcomings, limitations, and biases of the model to relevant stakeholders in ways that can be generally understood?
#
# ### E. Deployment
#  - [X] **E.1 Monitoring and evaluation**: Do we have a clear plan to monitor the model and its impacts after it is deployed (e.g., performance monitoring, regular audit of sample predictions, human review of high-stakes decisions, reviewing downstream impacts of errors or low-confidence decisions, testing for concept drift)?
#  - [X] **E.2 Redress**: Have we discussed with our organization a plan for response if users are harmed by the results (e.g., how does the data science team evaluate these cases and update analysis and models to prevent future harm)?
#  - [X] **E.3 Roll back**: Is there a way to turn off or roll back the model in production if necessary?
#  - [X] **E.4 Unintended use**: Have we taken steps to identify and prevent unintended uses and abuse of the model and do we have a plan to monitor these once the model is deployed?

# %% [markdown]
# ## Team Expectations

# %% [markdown]
# 1. Consistency in Elite STEM: We suspect that high-paying majors like Computer Science will keep a very tight and high GPA "floor" near 3.9 or 4.0 regardless of minor market fluctuations because the financial reward is so clear. This means their 25th percentile GPA will likely stay stuck at the top of the scale, showing very little room for lower-GPA students even in "off" years.
# 2. Market Signals as Leading Indicators: We expect to see a "lagged" effect where a rise in a major’s median salary in one year leads to a tougher GPA requirement for transfer students a year or two later. This would prove that UCSD applicants are paying attention to which degrees are becoming more valuable in the job market and are shifting their applications accordingly.
# 3. The Pre-Professional Outlier Effect: We think that "pre-med" majors like Human Biology will be an exception to the salary rule, keeping high GPA bars despite having lower immediate paychecks than engineering. The competition in these fields is probably fueled by the desire for high-prestige graduate school placements rather than just the first salary after college.

# %% [markdown]
# ## Project Timeline Proposal

# %% [markdown]
# Instructions: REPLACE the contents of this cell with your work
#
# Specify your team's specific project timeline. An example timeline has been provided. Changes the dates, times, names, and details to fit your group's plan.
#
# If you think you will need any special resources or training outside what we have covered in COGS 108 to solve your problem, then your proposal should state these clearly. For example, if you have selected a problem that involves implementing multiple neural networks, please state this so we can make sure you know what you’re doing and so we can point you to resources you will need to implement your project. Note that you are not required to use outside methods.
#
#
#
# | Meeting Date  | Meeting Time| Completed Before Meeting  | Discuss at Meeting |
# |---|---|---|---|
# | 2/5  |  1 PM | Scoping & Initial Data Pulls: Finalized the selection of 10 UCSD majors. Successfully extracted the raw 2022–2024 GPA percentile data (10th/25th/75th) from the Transfer by Major database.  | Review the "Redacted" entries in the data (where N < 5) and decide whether to substitute any of the 10 majors for programs with larger sample sizes. |
# | 2/19  |  10 AM |  Data Wrangling & Mapping: Cross-referenced major titles between the Admissions table and the Alumni Earnings dashboard. Created a mapping key to handle discrepancies. | Discuss the "Time Lag" issue: Admissions data is current (2024), but the most reliable salary data often reflects students who graduated 2 or 5 years ago. How do we best align these periods? |
# | 3/5 | 10 AM  | Visualizing Trends: Produced a series of scatter plots and trend lines showing the relationship between 25th percentile GPA shifts and median annual wages. Calculated the Year-over-Year (YoY) percentage change for both variables. | Analyze "Outlier Majors": Why does a major like Human Biology have a high GPA floor despite lower immediate earnings? Discuss the role of "Pre-Med" career pathways in driving selectivity.|
# | 3/14  | 6 PM  | Regression & Statistical Testing: Ran the primary regression models. Tested the strength of "Median Salary" as a predictor for "Admitted GPA" across the 10-major cohort. Checked for statistical significance (p-values). | Interpret the results: Does the data actually support our hypothesis of "Economic Rationality"? Discuss if UCSD’s "Capped Major" policies interfere with the salary-selectivity correlation. |
# | 3/18  | 12 PM  | Final Polish & Documentation: Assembled the final report. Verified all HTML citations and ensured that the "Prior Work" section aligns with our statistical findings. | Final walkthrough of the project. Ensure the conclusion specifically answers the original research question regarding UCSD-specific trends. |
